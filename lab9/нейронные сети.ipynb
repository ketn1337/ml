# %% [markdown]
# В этом занятии вам предстоит потренироваться построению нейронных сетей с помощью библиотеки Pytorch.

# %%
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split

import torch
from torch import nn
from torch.nn import functional as F

from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# # Часть 1. Датасет moons

# %%
X, y = make_moons(n_samples=10000, random_state=42, noise=0.1)

X
# Out:
# array([[ 0.45549318, -0.12550304],
#        [-0.70421731,  0.04130827],
#        [ 0.41379864,  0.79132194],
#        ...,
#        [-0.03803096,  0.24540791],
#        [ 0.8698024 ,  0.52329471],
#        [ 1.16429638, -0.3798397 ]])

# %%
plt.figure(figsize=(16, 10))
plt.title("Dataset")
plt.scatter(X[:, 0], X[:, 1], c=y, cmap="viridis")
plt.show()

# %% [markdown]
# Сделаем train/test split

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Загрузка данных
# В PyTorch загрузка данных как правило происходит налету (иногда датасеты не помещаются в оперативную память). Для этого используются две сущности `Dataset` и `DataLoader`.
#
# 1.   `Dataset` загружает каждый объект по отдельности.
#
# 2.   `DataLoader` группирует объекты из `Dataset` в батчи.
#
# Так как наш датасет достаточно маленький мы будем использовать `TensorDataset`. Все, что нам нужно, это перевести из массива numpy в тензор с типом `torch.float32`.
#
# ### Задание. Создайте тензоры с обучающими и тестовыми данными

# %%
X_train_t = torch.from_numpy(X_train).to(torch.float32)
y_train_t = torch.from_numpy(y_train).to(torch.float32)
X_val_t = torch.from_numpy(X_val).to(torch.float32)
y_val_t = torch.from_numpy(y_val).to(torch.float32)

# %% [markdown]
# Создаем `Dataset` и `DataLoader`.

# %%
train_dataset = TensorDataset(X_train_t, y_train_t)
val_dataset = TensorDataset(X_val_t, y_val_t)
train_dataloader = DataLoader(train_dataset, batch_size=128)
val_dataloader = DataLoader(val_dataset, batch_size=128)

# %% [markdown]
# ## Logistic regression
#
# **Напоминание**
# На входе у нас есть матрица объект-признак X и столбец-вектор $y$ – метки из $\{0, 1\}$ для каждого объекта. Мы хотим найти такую матрицу весов $W$ и смещение $b$ (bias), что наша модель $XW + b$ будет каким-то образом предсказывать класс объекта. Как видно на выходе наша модель может выдавать число в интервале от $(-\infty;\infty)$. Этот выход как правило называют "логитами" (logits). Нам необходимо перевести его на интервал от $[0;1]$ для того, чтобы он выдавал нам вероятность принадлежности объекта к кассу один, также лучше, чтобы эта функция была монотонной, быстро считалась, имела производную и на $-\infty$ имела значение $0$, а на $+\infty$ имела значение $1$. Такой класс функций называется сигмоидыю. Чаще всего в качестве сигмоида берут
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}.
# $$

# %% [markdown]
# ### Задание. Реализация логистической регрессии
#
# Вам необходимо написать модуль на PyTorch реализующий $logits = XW + b$, где $W$ и $b$ – параметры (`nn.Parameter`) модели. Иначе говоря, здесь мы реализуем своими руками модуль `nn.Linear` (в этом пункте его использование запрещено). Инициализируйте веса нормальным распределением (`torch.randn`).

# %%
class LinearRegression(nn.Module):
    def __init__(self, in_features: int, out_features: int, bias: bool = True):
        super().__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.weights = nn.Parameter(torch.randn((in_features, out_features)))
        self.bias = bias
        if bias:
            self.bias_term = nn.Parameter(torch.randn(out_features))

    def forward(self, x):
        x @= self.weights
        if self.bias:
            x += self.bias_term
        return x

# %%
linear_regression = LinearRegression(2, 1)
loss_function = nn.BCEWithLogitsLoss()
optimizer = torch.optim.SGD(linear_regression.parameters(), lr=0.05)

# %% [markdown]
# **Вопрос 1.** Сколько обучаемых параметров у получившейся модели? Имеется в виду суммарное количество отдельных числовых переменных, а не количество тензоров.

# %%
linear_regression.in_features + 1
# Out:
# 3

# %% [markdown]
# ### Train loop
#
# Вот псевдокод, который поможет вам разобраться в том, что происходит во время обучения
#
# ```python
# for epoch in range(max_epochs):  # <----------- итерируемся по датасету несколько раз
#     for x_batch, y_batch in dataset:  # <------ итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#         optimizer.zero_grad()  # <------------- обуляем градиенты модели
#         outp = model(x_batch)  # <------------- получаем "логиты" из модели
#         loss = loss_func(outp, y_batch)  # <--- считаем "лосс" для логистической регрессии
#         loss.backward()  # <------------------- считаем градиенты
#         optimizer.step()  # <------------------ делаем шаг градиентного спуска
#         if convergence:  # <------------------- в случае сходимости выходим из цикла
#             break
# ```
#
# В коде ниже добавлено логирование `accuracy` и `loss`.

# %% [markdown]
# ### Задание. Реализация цикла обучения

# %%
tol = 1e-3
losses = []
max_epochs = 100
prev_weights = torch.zeros_like(linear_regression.weights)
stop_it = False
for epoch in range(max_epochs):
    for it, (X_batch, y_batch) in enumerate(train_dataloader):
        optimizer.zero_grad()
        outp = linear_regression.forward(X_batch).squeeze(1)
        loss = loss_function(outp, y_batch)
        loss.backward()
        losses.append(loss.detach().flatten()[0])
        optimizer.step()
        probabilities = torch.sigmoid(outp)
        preds = (probabilities > 0.5).type(torch.long)
        batch_acc = (preds.flatten() == y_batch).type(torch.float32).sum() / y_batch.size(0)

        if (it + epoch * len(train_dataloader)) % 100 == 0:
            print(f"Iteration: {it + epoch * len(train_dataloader)}\nBatch accuracy: {batch_acc}")
        current_weights = linear_regression.weights.detach().clone()
        if (prev_weights - current_weights).abs().max() < tol:
            print(f"\nIteration: {it + epoch * len(train_dataloader)}.Convergence. Stopping iterations.")
            stop_it = True
            break
        prev_weights = current_weights
    if stop_it:
        break
# Out:
# Iteration: 0
# Batch accuracy: 0.5234375
# Iteration: 100
# Batch accuracy: 0.734375
# Iteration: 200
# Batch accuracy: 0.78125
# Iteration: 300
# Batch accuracy: 0.84375
# Iteration: 400
# Batch accuracy: 0.8359375
# Iteration: 500
# Batch accuracy: 0.875
# Iteration: 600
# Batch accuracy: 0.859375
# Iteration: 700
# Batch accuracy: 0.8046875
# Iteration: 800
# Batch accuracy: 0.8203125
#
# Iteration: 873.Convergence. Stopping iterations.

# %% [markdown]
# ### Визуализируем результаты

# %%
plt.figure(figsize=(12, 8))
plt.plot(range(len(losses)), losses)
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.show()

# %%
xx, yy = np.mgrid[-1.5:2.5:.01, -1.:1.5:.01]
grid = np.c_[xx.ravel(), yy.ravel()]
batch = torch.from_numpy(grid).type(torch.float32)
with torch.no_grad():
    probs = torch.sigmoid(linear_regression(batch).reshape(xx.shape))
    probs = probs.numpy().reshape(xx.shape)

f, ax = plt.subplots(figsize=(16, 10))
ax.set_title("Decision boundary", fontsize=14)
contour = ax.contourf(xx, yy, probs, 25, cmap="RdBu",
                      vmin=0, vmax=1)
ax_c = f.colorbar(contour)
ax_c.set_label("$P(y = 1)$")
ax_c.set_ticks([0, .25, .5, .75, 1])

ax.scatter(X[100:,0], X[100:, 1], c=y[100:], s=50,
           cmap="RdBu", vmin=-.2, vmax=1.2,
           edgecolor="white", linewidth=1)

ax.set(xlabel="$X_1$", ylabel="$X_2$")
plt.show()

# %% [markdown]
# ### Задание. Реализуйте predict и посчитайте accuracy на test.

# %%
@torch.no_grad()
def predict(dataloader, model):
    model.eval()
    predictions = np.array([])
    for x_batch, _ in dataloader:
        probabilities = torch.sigmoid(model(x_batch))
        preds = (probabilities > 0.5).type(torch.long)
        predictions = np.hstack((predictions, preds.numpy().flatten()))
    return predictions.flatten()

# %%
from sklearn.metrics import accuracy_score

preds = predict(val_dataloader, linear_regression)
accuracy_score(y_val_t.numpy(), preds)
# Out:
# 0.8592

# %% [markdown]
# **Вопрос 2**
#
# Какое `accuracy` получается после обучения?
#
# **Ответ:** 0.8592

# %% [markdown]
# # Часть 2. Датасет MNIST

# %%
import os
from torchvision.datasets import MNIST
from torchvision import transforms as tfs


data_tfs = tfs.Compose([
    tfs.ToTensor(),
    tfs.Normalize((0.5), (0.5))
])

# install for train and test
root = './'
train_dataset = MNIST(root, train=True,  transform=data_tfs, download=True)
val_dataset  = MNIST(root, train=False, transform=data_tfs, download=True)

train_dataloader = DataLoader(train_dataset, batch_size=128)
valid_dataloader = DataLoader(val_dataset, batch_size=128)

# %% [markdown]
# ## Часть 2.1. Полносвязные нейронные сети

# %%
class Identical(nn.Module):
    def forward(self, x):
        return x

# %% [markdown]
# ### Задание. Простая полносвязная нейронная сеть
#
# Создайте полносвязную нейронную сеть с помощью класса Sequential. Сеть состоит из:
# * Уплощения матрицы в вектор (nn.Flatten);
# * Двух скрытых слоёв из 128 нейронов с активацией nn.ELU;
# * Выходного слоя с 10 нейронами.
#
# Задайте лосс для обучения (кросс-энтропия).

# %%
activation = nn.ELU()

model = nn.Sequential(
    nn.Flatten(),
    nn.Linear(784, 128),
    activation,
    nn.Linear(128, 128),
    activation,
    nn.Linear(128, 10)
)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_dataloader, "valid": valid_dataloader}

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# ### Train loop (seriously)
#
#
#
# ```python
# for epoch in range(max_epochs):  # <--------------- итерируемся по датасету несколько раз
#     for k, dataloader in loaders.items():  # <----- несколько dataloader для train / valid / test
#         for x_batch, y_batch in dataloader:  # <--- итерируемся по датасету. Так как мы используем SGD а не GD, то берем батчи заданного размера
#             if k == "train":
#                 model.train()  # <------------------ переводим модель в режим train
#                 optimizer.zero_grad()  # <--------- обнуляем градиенты модели
#                 outp = model(x_batch)
#                 loss = criterion(outp, y_batch) # <-считаем "лосс" для логистической регрессии
#                 loss.backward()  # <--------------- считаем градиенты
#                 optimizer.step()  # <-------------- делаем шаг градиентного спуска
#             else:  # <----------------------------- test/eval
#                 model.eval()  # <------------------ переводим модель в режим eval
#                 with torch.no_grad():  # <--------- НЕ считаем градиенты
#                     outp = model(x_batch)  # <------------- получаем "логиты" из модели
#             count_metrics(outp, y_batch)  # <-------------- считаем метрики
# ```

# %% [markdown]
# ### Задание. Дополните цикл обучения.

# %%
max_epochs = 10
accuracy = {"train": [], "valid": []}

for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0

        for x_batch, y_batch in dataloader:
            if k == "train":
                model.train()
                optimizer.zero_grad()
                outp = model(x_batch)
                loss = criterion(outp, y_batch)
                loss.backward()
                optimizer.step()
            else:
                model.eval()
                with torch.no_grad():
                    outp = model(x_batch)

            preds = outp.argmax(-1)
            correct = (preds == y_batch).sum()
            all = len(y_batch)
            epoch_correct += correct.item()
            epoch_all += all

        if k == "train":
            print(f"Epoch: {epoch + 1}")

        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct / epoch_all)
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.88135
# Loader: valid. Accuracy: 0.9258
# Epoch: 2
# Loader: train. Accuracy: 0.9430333333333333
# Loader: valid. Accuracy: 0.9446
# Epoch: 3
# Loader: train. Accuracy: 0.9585833333333333
# Loader: valid. Accuracy: 0.9554
# Epoch: 4
# Loader: train. Accuracy: 0.9675666666666667
# Loader: valid. Accuracy: 0.9649
# Epoch: 5
# Loader: train. Accuracy: 0.9733833333333334
# Loader: valid. Accuracy: 0.9678
# Epoch: 6
# Loader: train. Accuracy: 0.9783166666666666
# Loader: valid. Accuracy: 0.9692
# Epoch: 7
# Loader: train. Accuracy: 0.9817166666666667
# Loader: valid. Accuracy: 0.9681
# Epoch: 8
# Loader: train. Accuracy: 0.9835833333333334
# Loader: valid. Accuracy: 0.9666
# Epoch: 9
# Loader: train. Accuracy: 0.9848666666666667
# Loader: valid. Accuracy: 0.9661
# Epoch: 10
# Loader: train. Accuracy: 0.9866333333333334
# Loader: valid. Accuracy: 0.9685

# %% [markdown]
# ### Задание. Протестируйте разные функции активации.
# Попробуйте разные функции активации. Для каждой функции активации посчитайте массив validation accuracy. Лучше реализовать это в виде функции, берущей на вход активацию и получающей массив из accuracies.

# %%
elu_accuracy = accuracy["valid"]

# %%
def test_activation_function(activation):
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(784, 128),
        activation,
        nn.Linear(128, 128),
        activation,
        nn.Linear(128, 10),
    )
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters())

    accuracy = {"train": [], "valid": []}
    max_epochs = 10

    for epoch in range(max_epochs):
        for k, dataloader in loaders.items():
            epoch_correct = 0
            epoch_all = 0

            for x_batch, y_batch in dataloader:
                if k == "train":
                    model.train()
                    optimizer.zero_grad()
                    outp = model(x_batch)
                    loss = criterion(outp, y_batch)
                    loss.backward()
                    optimizer.step()
                else:
                    model.eval()
                    with torch.no_grad():
                        outp = model(x_batch)

                preds = outp.argmax(-1)
                correct = (preds == y_batch).sum()
                all = len(y_batch)
                epoch_correct += correct.item()
                epoch_all += all

            if k == "train":
                print(f"Epoch: {epoch + 1}")
            print(f"Activation: {activation}. Loader: {k}. Accuracy: {epoch_correct / epoch_all}")

            accuracy[k].append(epoch_correct / epoch_all)
            
    return accuracy["valid"]

# %%
plain_accuracy = test_activation_function(Identical())
relu_accuracy = test_activation_function(nn.ReLU())
leaky_relu_accuracy = test_activation_function(nn.LeakyReLU())
tanh_accuracy = test_activation_function(nn.Tanh())
plain_accuracy, relu_accuracy, leaky_relu_accuracy, tanh_accuracy
# Out:
# Epoch: 1
# Activation: Identical(). Loader: train. Accuracy: 0.8630666666666666
# Activation: Identical(). Loader: valid. Accuracy: 0.8823
# Epoch: 2
# Activation: Identical(). Loader: train. Accuracy: 0.8958166666666667
# Activation: Identical(). Loader: valid. Accuracy: 0.9009
# Epoch: 3
# Activation: Identical(). Loader: train. Accuracy: 0.9005
# Activation: Identical(). Loader: valid. Accuracy: 0.9037
# Epoch: 4
# Activation: Identical(). Loader: train. Accuracy: 0.9024333333333333
# Activation: Identical(). Loader: valid. Accuracy: 0.9033
# Epoch: 5
# Activation: Identical(). Loader: train. Accuracy: 0.9040166666666667
# Activation: Identical(). Loader: valid. Accuracy: 0.9024
# Epoch: 6
# Activation: Identical(). Loader: train. Accuracy: 0.9055666666666666
# Activation: Identical(). Loader: valid. Accuracy: 0.9016
# Epoch: 7
# Activation: Identical(). Loader: train. Accuracy: 0.9065833333333333
# Activation: Identical(). Loader: valid. Accuracy: 0.9022
# Epoch: 8
# Activation: Identical(). Loader: train. Accuracy: 0.9078166666666667
# Activation: Identical(). Loader: valid. Accuracy: 0.9026
# Epoch: 9
# Activation: Identical(). Loader: train. Accuracy: 0.9090333333333334
# Activation: Identical(). Loader: valid. Accuracy: 0.9033
# Epoch: 10
# Activation: Identical(). Loader: train. Accuracy: 0.9099166666666667
# Activation: Identical(). Loader: valid. Accuracy: 0.9036
# Epoch: 1
# Activation: ReLU(). Loader: train. Accuracy: 0.8636166666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.919
# Epoch: 2
# Activation: ReLU(). Loader: train. Accuracy: 0.9314166666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.9448
# Epoch: 3
# Activation: ReLU(). Loader: train. Accuracy: 0.9516
# Activation: ReLU(). Loader: valid. Accuracy: 0.9548
# Epoch: 4
# Activation: ReLU(). Loader: train. Accuracy: 0.9625166666666667
# Activation: ReLU(). Loader: valid. Accuracy: 0.9595
# Epoch: 5
# Activation: ReLU(). Loader: train. Accuracy: 0.9689333333333333
# Activation: ReLU(). Loader: valid. Accuracy: 0.9624
# Epoch: 6
# Activation: ReLU(). Loader: train. Accuracy: 0.9732666666666666
# Activation: ReLU(). Loader: valid. Accuracy: 0.9659
# Epoch: 7
# Activation: ReLU(). Loader: train. Accuracy: 0.9760166666666666
# Activation: ReLU(). Loader: valid. Accuracy: 0.9658
# Epoch: 8
# Activation: ReLU(). Loader: train. Accuracy: 0.9781
# Activation: ReLU(). Loader: valid. Accuracy: 0.9667
# Epoch: 9
# Activation: ReLU(). Loader: train. Accuracy: 0.9807833333333333
# Activation: ReLU(). Loader: valid. Accuracy: 0.969
# Epoch: 10
# Activation: ReLU(). Loader: train. Accuracy: 0.98255
# Activation: ReLU(). Loader: valid. Accuracy: 0.9721
# Epoch: 1
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.8684
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9242
# Epoch: 2
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.93755
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9477
# Epoch: 3
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.95415
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9548
# Epoch: 4
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.96425
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9613
# Epoch: 5
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9697833333333333
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9637
# Epoch: 6
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9744166666666667
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9686
# Epoch: 7
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9779833333333333
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9653
# Epoch: 8
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.98
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9682
# Epoch: 9
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.9816833333333334
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.965
# Epoch: 10
# Activation: LeakyReLU(negative_slope=0.01). Loader: train. Accuracy: 0.98385
# Activation: LeakyReLU(negative_slope=0.01). Loader: valid. Accuracy: 0.9672
# Epoch: 1
# Activation: Tanh(). Loader: train. Accuracy: 0.8873166666666666
# Activation: Tanh(). Loader: valid. Accuracy: 0.9394
# Epoch: 2
# Activation: Tanh(). Loader: train. Accuracy: 0.9446166666666667
# Activation: Tanh(). Loader: valid. Accuracy: 0.9552
# Epoch: 3
# Activation: Tanh(). Loader: train. Accuracy: 0.9588666666666666
# Activation: Tanh(). Loader: valid. Accuracy: 0.9631
# Epoch: 4
# Activation: Tanh(). Loader: train. Accuracy: 0.96615
# Activation: Tanh(). Loader: valid. Accuracy: 0.9688
# Epoch: 5
# Activation: Tanh(). Loader: train. Accuracy: 0.9709666666666666
# Activation: Tanh(). Loader: valid. Accuracy: 0.966
# Epoch: 6
# Activation: Tanh(). Loader: train. Accuracy: 0.97455
# Activation: Tanh(). Loader: valid. Accuracy: 0.9641
# Epoch: 7
# Activation: Tanh(). Loader: train. Accuracy: 0.97775
# Activation: Tanh(). Loader: valid. Accuracy: 0.963
# Epoch: 8
# Activation: Tanh(). Loader: train. Accuracy: 0.9806166666666667
# Activation: Tanh(). Loader: valid. Accuracy: 0.9657
# Epoch: 9
# Activation: Tanh(). Loader: train. Accuracy: 0.9831833333333333
# Activation: Tanh(). Loader: valid. Accuracy: 0.964
# Epoch: 10
# Activation: Tanh(). Loader: train. Accuracy: 0.98295
# Activation: Tanh(). Loader: valid. Accuracy: 0.9693
# ([0.8823,
#   0.9009,
#   0.9037,
#   0.9033,
#   0.9024,
#   0.9016,
#   0.9022,
#   0.9026,
#   0.9033,
#   0.9036],
#  [0.919,
#   0.9448,
#   0.9548,
#   0.9595,
#   0.9624,
#   0.9659,
#   0.9658,
#   0.9667,
#   0.969,
#   0.9721],
#  [0.9242,
#   0.9477,
#   0.9548,
#   0.9613,
#   0.9637,
#   0.9686,
#   0.9653,
#   0.9682,
#   0.965,
#   0.9672],
#  [0.9394, 0.9552, 0.9631, 0.9688, 0.966, 0.9641, 0.963, 0.9657, 0.964, 0.9693])

# %% [markdown]
# ### Accuracy
# Построим график accuracy/epoch для каждой функции активации.

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), plain_accuracy, label="No activation", linewidth=2)
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
plt.figure(figsize=(16, 10))
plt.title("Valid accuracy")
plt.plot(range(max_epochs), relu_accuracy, label="ReLU activation", linewidth=2)
plt.plot(range(max_epochs), leaky_relu_accuracy, label="LeakyReLU activation", linewidth=2)
plt.plot(range(max_epochs), elu_accuracy, label="ELU activation", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %% [markdown]
# **Вопрос 3.** Какая из активаций показала наивысший `accuracy` к концу обучения?
#
# **Ответ:** ReLU
